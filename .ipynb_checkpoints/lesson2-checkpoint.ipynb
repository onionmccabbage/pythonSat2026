# %% [markdown]
# ### Using Python, Numpy and Pandas

# %%
# we usually import tools at the top
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
print(np.version)
# Out:
# <module 'numpy.version' from 'C:\\Users\\rb17\\anaconda3\\Lib\\site-packages\\numpy\\version.py'>

# %%
np.random.randint(10**7)
# Numpy gives us arrays
a = np.array([5,7,3,9])
b = np.array([1,2,3,4])
type(b)
a*b
# Out:
# array([ 5, 14,  9, 36])

# %% [markdown]
# ### Pure Statistics

# %%
f = np.random.normal(10, 3, 10**4)
f[4:8]
# Out:
# array([ 9.3367956 ,  9.65810699,  5.03098105, 10.24501903])

# %%
# We may use simple statements to get stats
f.min() # also mean() and min()
# Out:
# np.float64(-1.5759645443074266)

# %% [markdown]
# ### Pandas
# We may load external data

# %%
s = pd.read_csv('StockData/sp500.csv')
# or grab from the internet
s = pd.read_csv('https://raw.githubusercontent.com/onionmccabbage/pythonSat2026/refs/heads/main/StockData/SP500.csv')
s
# Out:
#           Date         Open         High          Low        Close  \
# 0      9/30/13  1687.260010  1687.260010  1674.989990  1681.550049
# 1     10/01/13  1682.410034  1696.550049  1682.069946  1695.000000
# 2     10/02/13  1691.900024  1693.869995  1680.339966  1693.869995
# 3     10/03/13  1692.349976  1692.349976  1670.359985  1678.660034
# 4     10/04/13  1678.790039  1691.939941  1677.329956  1690.500000
# ...        ...          ...          ...          ...          ...
# 1255   9/24/18  2921.830078  2923.790039  2912.629883  2919.370117
# 1256   9/25/18  2921.750000  2923.949951  2913.699951  2915.560059
# 1257   9/26/18  2916.979980  2931.149902  2903.280029  2905.969971
# 1258   9/27/18  2911.649902  2927.219971  2909.270020  2914.000000
# 1259   9/28/18  2910.030029  2920.530029  2907.500000  2913.979980
#
#         Adj Close      Volume
# 0     1681.550049  3308630000
# 1     1695.000000  3238690000
# 2     1693.869995  3148600000
# 3     1678.660034  3279650000
# ...
