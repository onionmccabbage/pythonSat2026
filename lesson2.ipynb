# %% [markdown]
# ### Using Python, Numpy and Pandas

# %%
# we usually import tools at the top
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
print(np.version)
# Out:
# <module 'numpy.version' from 'C:\\Users\\rb17\\anaconda3\\Lib\\site-packages\\numpy\\version.py'>

# %%
np.random.randint(10**7)
# Numpy gives us arrays
a = np.array([5,7,3,9])
b = np.array([1,2,3,4])
type(b)
a*b
# Out:
# array([ 5, 14,  9, 36])

# %% [markdown]
# ### Pure Statistics

# %%
f = np.random.normal(10, 3, 10**4)
f[4:8]
# Out:
# array([ 9.3367956 ,  9.65810699,  5.03098105, 10.24501903])

# %%
# We may use simple statements to get stats
f.min() # also mean() and min()
# Out:
# np.float64(-1.5759645443074266)

# %% [markdown]
# ### Pandas
# We may load external data

# %%
s = pd.read_csv('StockData/sp500.csv')
# or grab from the internet
# s = pd.read_csv('https://raw.githubusercontent.com/onionmccabbage/pythonSat2026/refs/heads/main/StockData/SP500.csv')

# %%
# see what we have
s # DataFrame (NB Python is case sensitive)
s.info()  
s
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1260 non-null   str
#  1   Open       1260 non-null   float64
#  2   High       1260 non-null   float64
#  3   Low        1260 non-null   float64
#  4   Close      1260 non-null   float64
#  5   Adj Close  1260 non-null   float64
#  6   Volume     1260 non-null   int64
#  7   realDate   1260 non-null   datetime64[us]
# dtypes: datetime64[us](1), float64(5), int64(1), str(1)
# memory usage: 87.8 KB
#           Date         Open         High          Low        Close  \
# 0      9/30/13  1687.260010  1687.260010  1674.989990  1681.550049
# 1     10/01/13  1682.410034  1696.550049  1682.069946  1695.000000
# 2     10/02/13  1691.900024  1693.869995  1680.339966  1693.869995
# 3     10/03/13  1692.349976  1692.349976  1670.359985  1678.660034
# ...

# %%
# we may need to convert strings to dates
# optionally we may declare a format, which the the EXISTING string representation
s['realDate'] = pd.to_datetime( s['Date'], format='%m/%d/%y' )
s
# Out:
#           Date         Open         High          Low        Close  \
# 0      9/30/13  1687.260010  1687.260010  1674.989990  1681.550049
# 1     10/01/13  1682.410034  1696.550049  1682.069946  1695.000000
# 2     10/02/13  1691.900024  1693.869995  1680.339966  1693.869995
# 3     10/03/13  1692.349976  1692.349976  1670.359985  1678.660034
# 4     10/04/13  1678.790039  1691.939941  1677.329956  1690.500000
# ...        ...          ...          ...          ...          ...
# 1255   9/24/18  2921.830078  2923.790039  2912.629883  2919.370117
# 1256   9/25/18  2921.750000  2923.949951  2913.699951  2915.560059
# 1257   9/26/18  2916.979980  2931.149902  2903.280029  2905.969971
# 1258   9/27/18  2911.649902  2927.219971  2909.270020  2914.000000
# 1259   9/28/18  2910.030029  2920.530029  2907.500000  2913.979980
#
#         Adj Close      Volume   realDate
# 0     1681.550049  3308630000 2013-09-30
# 1     1695.000000  3238690000 2013-10-01
# ...

# %%
# We can also choose to use any column as an index
s.set_index( 'realDate' )
# Out:
#                 Date         Open         High          Low        Close  \
# realDate
# 2013-09-30   9/30/13  1687.260010  1687.260010  1674.989990  1681.550049
# 2013-10-01  10/01/13  1682.410034  1696.550049  1682.069946  1695.000000
# 2013-10-02  10/02/13  1691.900024  1693.869995  1680.339966  1693.869995
# 2013-10-03  10/03/13  1692.349976  1692.349976  1670.359985  1678.660034
# 2013-10-04  10/04/13  1678.790039  1691.939941  1677.329956  1690.500000
# ...              ...          ...          ...          ...          ...
# 2018-09-24   9/24/18  2921.830078  2923.790039  2912.629883  2919.370117
# 2018-09-25   9/25/18  2921.750000  2923.949951  2913.699951  2915.560059
# 2018-09-26   9/26/18  2916.979980  2931.149902  2903.280029  2905.969971
# 2018-09-27   9/27/18  2911.649902  2927.219971  2909.270020  2914.000000
# 2018-09-28   9/28/18  2910.030029  2920.530029  2907.500000  2913.979980
#
#               Adj Close      Volume
# realDate
# ...

# %%
# We often choose to do all these steps at once
sp500 = pd.read_csv('StockData/sp500.csv', parse_dates=True, date_format='%m/%d/%y', index_col='Date')

# %%
sp500.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# m

# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-09-30  1687.260010  1687.260010  1674.989990  1681.550049  1681.550049
# 2013-10-01  1682.410034  1696.550049  1682.069946  1695.000000  1695.000000
# 2013-10-02  1691.900024  1693.869995  1680.339966  1693.869995  1693.869995
# 2013-10-03  1692.349976  1692.349976  1670.359985  1678.660034  1678.660034
# 2013-10-04  1678.790039  1691.939941  1677.329956  1690.500000  1690.500000
# ...                 ...          ...          ...          ...          ...
# 2013-12-24  1828.020020  1833.319946  1828.020020  1833.319946  1833.319946
# 2013-12-26  1834.959961  1842.839966  1834.959961  1842.020020  1842.020020
# 2013-12-27  1842.969971  1844.890015  1839.810059  1841.400024  1841.400024
# 2013-12-30  1841.469971  1842.469971  1838.770020  1841.069946  1841.069946
# 2013-12-31  1842.609985  1849.439941  1842.410034  1848.359985  1848.359985
#
#                 Volume
# Date
# ...

# %%
# we may access onespecific cell like this
sp500.head(3)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-09-30  1687.260010  1687.260010  1674.989990  1681.550049  1681.550049
# 2013-10-01  1682.410034  1696.550049  1682.069946  1695.000000  1695.000000
# 2013-10-02  1691.900024  1693.869995  1680.339966  1693.869995  1693.869995
#
#                 Volume
# Date
# 2013-09-30  3308630000
# 2013-10-01  3238690000
# 2013-10-02  3148600000

# %%
sp500.iloc[2]['Close']
# Out:
# np.float64(1693.869995)

# %%
h = sp500.loc['2016-12-01']['High']
l = sp500.loc['2016-12-01']['Low']
h-l
# Out:
# np.float64(15.1601569999998)

# %%
sp500['Open']
sp500[ ['Close', 'Open'] ]  # we use a list for the columns we wish to see
sp500.info()
d = pd.read
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 1260 entries, 2013-09-30 to 2018-09-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1260 non-null   float64
#  1   High       1260 non-null   float64
#  2   Low        1260 non-null   float64
#  3   Close      1260 non-null   float64
#  4   Adj Close  1260 non-null   float64
#  5   Volume     1260 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 101.2 KB

# %%
# we may slice just a few rows
sp500.loc['2013-10-02':'2014-10-02']
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-10-02  1691.900024  1693.869995  1680.339966  1693.869995  1693.869995
# 2013-10-03  1692.349976  1692.349976  1670.359985  1678.660034  1678.660034
# 2013-10-04  1678.790039  1691.939941  1677.329956  1690.500000  1690.500000
# 2013-10-07  1687.150024  1687.150024  1674.699951  1676.119995  1676.119995
# 2013-10-08  1676.219971  1676.790039  1655.030029  1655.449951  1655.449951
# ...                 ...          ...          ...          ...          ...
# 2014-09-26  1966.219971  1986.369995  1966.219971  1982.849976  1982.849976
# 2014-09-29  1978.959961  1981.280029  1964.040039  1977.800049  1977.800049
# 2014-09-30  1978.209961  1985.170044  1968.959961  1972.290039  1972.290039
# 2014-10-01  1971.439941  1971.439941  1941.719971  1946.160034  1946.160034
# 2014-10-02  1945.829956  1952.319946  1926.030029  1946.170044  1946.170044
#
#                 Volume
# Date
# ...

# %%
# slicing with loc
sp500['2013-10-02':'2014-10-02'] # this defaults to using loc
sp500.loc['2013-10-02':'2014-10-02'] # NB sp500.iloc[32:57] uses row numbers
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-10-02  1691.900024  1693.869995  1680.339966  1693.869995  1693.869995
# 2013-10-03  1692.349976  1692.349976  1670.359985  1678.660034  1678.660034
# 2013-10-04  1678.790039  1691.939941  1677.329956  1690.500000  1690.500000
# 2013-10-07  1687.150024  1687.150024  1674.699951  1676.119995  1676.119995
# 2013-10-08  1676.219971  1676.790039  1655.030029  1655.449951  1655.449951
# ...                 ...          ...          ...          ...          ...
# 2014-09-26  1966.219971  1986.369995  1966.219971  1982.849976  1982.849976
# 2014-09-29  1978.959961  1981.280029  1964.040039  1977.800049  1977.800049
# 2014-09-30  1978.209961  1985.170044  1968.959961  1972.290039  1972.290039
# 2014-10-01  1971.439941  1971.439941  1941.719971  1946.160034  1946.160034
# 2014-10-02  1945.829956  1952.319946  1926.030029  1946.170044  1946.170044
#
#                 Volume
# Date
# ...

# %%
# Plotting Data
sp500[ ['High', 'Low'] ].plot() # we use built-in plotting from Pandas
# Out:
# <Axes: xlabel='Date'>

# %%
# Working with logs
sp500['logClose'] = np.log( sp500['Close'] )
# sp500['wibbly'] = sp500['Open']*0.5
sp500['logReturns'] = sp500['logClose'].diff()
sp500
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-09-30  1687.260010  1687.260010  1674.989990  1681.550049  1681.550049
# 2013-10-01  1682.410034  1696.550049  1682.069946  1695.000000  1695.000000
# 2013-10-02  1691.900024  1693.869995  1680.339966  1693.869995  1693.869995
# 2013-10-03  1692.349976  1692.349976  1670.359985  1678.660034  1678.660034
# 2013-10-04  1678.790039  1691.939941  1677.329956  1690.500000  1690.500000
# ...                 ...          ...          ...          ...          ...
# 2018-09-24  2921.830078  2923.790039  2912.629883  2919.370117  2919.370117
# 2018-09-25  2921.750000  2923.949951  2913.699951  2915.560059  2915.560059
# 2018-09-26  2916.979980  2931.149902  2903.280029  2905.969971  2905.969971
# 2018-09-27  2911.649902  2927.219971  2909.270020  2914.000000  2914.000000
# 2018-09-28  2910.030029  2920.530029  2907.500000  2913.979980  2913.979980
#
# ...

# %%
# Quick summaries
sp500['Close'].mean()
# Out:
# np.float64(2208.5791827325397)
