# %% [markdown]
# ### Using Python, Numpy and Pandas

# %%
# we usually import tools at the top
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
print(np.version)
# Out:
# <module 'numpy.version' from 'C:\\Users\\rb17\\anaconda3\\Lib\\site-packages\\numpy\\version.py'>

# %%
np.random.randint(10**7)
# Numpy gives us arrays
a = np.array([5,7,3,9])
b = np.array([1,2,3,4])
type(b)
a*b
# Out:
# array([ 5, 14,  9, 36])

# %% [markdown]
# ### Pure Statistics

# %%
f = np.random.normal(10, 3, 10**4)
f[4:8]
# Out:
# array([ 9.59593534,  8.98900637, 11.218112  ,  9.94062358])
